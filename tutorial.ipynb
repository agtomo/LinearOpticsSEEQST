# %%
import sys
sys.path.insert(0, '..')
from SEEQST_LOQC import *

# %%
N = 2

# Sequential build
circ = OpticalCircuit(N)
# circ.add_gate("CNOT", i=1, j=3)
circ.add_gate("Ry", i=2)
# circ.add_gate("Rx", i=2)

circ.summary()
# Out:
# ===== Optical Circuit =====
# Stage 0: PhasePlate | loc=(0,) | {}
# Stage 0: BS         | loc=((0,), (1,)) | {}
# Stage 1: BS         | loc=((0,), (1,)) | {}
# ===========================
